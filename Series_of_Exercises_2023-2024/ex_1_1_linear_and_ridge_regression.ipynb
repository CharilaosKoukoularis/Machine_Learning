# %%
import pandas as pd

wine_data = pd.read_csv('../../Matlab_Projects/Machine_Learning/ML2023-24-hwk1.csv', sep=';')
display(wine_data)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
from sklearn.preprocessing import StandardScaler
standardscaler = StandardScaler().fit(wine_data)#.drop(labels='quality',axis=1),wine_data['quality'])
normalized_data = pd.DataFrame(standardscaler.transform(wine_data))#.drop(labels='quality',axis=1)))
normalized_data.columns = wine_data.columns#.drop(labels='quality',axis=1).columns
display(normalized_data)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0         -0.528360          0.961877    -1.391472       -0.453218  -0.243707
# 1         -0.298547          1.967442    -1.391472        0.043416   0.223875
# 2         -0.298547          1.297065    -1.186070       -0.169427   0.096353
# 3          1.654856         -1.384443     1.484154       -0.453218  -0.264960
# 4         -0.528360          0.961877    -1.391472       -0.453218  -0.243707
# ...             ...               ...          ...             ...        ...
# 1594      -1.217796          0.403229    -0.980669       -0.382271   0.053845
# 1595      -1.390155          0.123905    -0.877968       -0.240375  -0.541259
# 1596      -1.160343         -0.099554    -0.723916       -0.169427  -0.243707
# 1597      -1.390155          0.654620    -0.775267       -0.382271  -0.264960
# 1598      -1.332702         -1.216849     1.021999        0.752894  -0.434990
#
# ...

# %%
print(normalized_data.mean(axis='index'),normalized_data.std(axis='index'))
print(wine_data.mean(axis='index'),wine_data.std(axis='index'))
# Out:
# fixed acidity           3.435512e-16
# volatile acidity        1.699704e-16
# citric acid             4.335355e-16
# residual sugar         -1.905223e-16
# chlorides               3.836136e-16
# free sulfur dioxide     1.432042e-16
# total sulfur dioxide    1.289532e-16
# density                -3.482795e-14
# pH                      3.002879e-15
# sulphates               7.639596e-16
# alcohol                 9.437243e-16
# quality                -8.051373e-16
# dtype: float64 fixed acidity           1.000313
# volatile acidity        1.000313
# citric acid             1.000313
# residual sugar          1.000313
# chlorides               1.000313
# free sulfur dioxide     1.000313
# total sulfur dioxide    1.000313
# density                 1.000313
# pH                      1.000313
# sulphates               1.000313
# alcohol                 1.000313
# quality                 1.000313
# dtype: float64
# fixed acidity            8.319637
# volatile acidity         0.527821
# ...

# %%
import matplotlib.pyplot as plt
plt.figure()
wine_data.hist(bins=30,figsize=(20,10))
plt.show()

plt.figure()
normalized_data.hist(bins=30,figsize=(20,10))
plt.show()

# %%
import seaborn as sns

sns.pairplot(normalized_data, kind='reg', plot_kws={'line_kws':{'color':'red'}})

# %%
X_train = normalized_data[:100].drop(columns='quality', axis=1)
y_train = normalized_data[:100]['quality']

X_test = normalized_data[100:150].drop(columns='quality', axis=1)
y_test = normalized_data[100:150]['quality']

# %%
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_squared_error

l = [0, 10, 100, 200]

models = [Ridge(alpha=l[0]), Ridge(alpha=l[1]), Ridge(alpha=l[2]), Ridge(alpha=l[3])]

models[0].fit(X=X_train, y=y_train)
models[1].fit(X=X_train, y=y_train)
models[2].fit(X=X_train, y=y_train)
models[3].fit(X=X_train, y=y_train)

y_pred = [models[0].predict(X=X_train),
          models[1].predict(X=X_train),
          models[2].predict(X=X_train),
          models[3].predict(X=X_train),
          models[0].predict(X=X_test),
          models[1].predict(X=X_test),
          models[2].predict(X=X_test),
          models[3].predict(X=X_test),
]
rmse = [
    mean_squared_error(y_true=y_train, y_pred=y_pred[0]),
    mean_squared_error(y_true=y_train, y_pred=y_pred[1]),
    mean_squared_error(y_true=y_train, y_pred=y_pred[2]),
    mean_squared_error(y_true=y_train, y_pred=y_pred[3]),
    mean_squared_error(y_true=y_test, y_pred=y_pred[4]),
    mean_squared_error(y_true=y_test, y_pred=y_pred[5]),
    mean_squared_error(y_true=y_test, y_pred=y_pred[6]),
    mean_squared_error(y_true=y_test, y_pred=y_pred[7]),
]

rmse = pd.DataFrame([rmse[0:4], rmse[4:8]])
rmse.columns = ['Linear Regression λ = 0',
                'Ridge Regression λ = 10', 
                'Ridge Regression λ = 100', 
                'Ridge Regression λ = 200']

display(rmse)
# Out:
#    Linear Regression λ = 0  Ridge Regression λ = 10  Ridge Regression λ = 100  \
# 0                  0.48993                 0.502195                  0.584038
# 1                  0.54838                 0.421458                  0.382388
#
#    Ridge Regression λ = 200
# 0                  0.609276
# 1                  0.403052

# %%
display(models[0].coef_,models[1].coef_,models[2].coef_,models[3].coef_)
# Out:
# array([ 1.74707568e-01, -4.31490869e-01, -3.40898082e-01,  3.21920245e-03,
#        -1.55086872e-04,  2.40043947e-01, -2.74358499e-01, -9.18677101e-02,
#        -1.45278750e-01,  3.38141655e-02,  3.23773125e-01])
# array([ 0.10142845, -0.33115146, -0.22859546,  0.00887057, -0.00784322,
#         0.16208866, -0.21070756, -0.05647638, -0.10308041,  0.03621796,
#         0.20760913])
# array([ 0.02652312, -0.12237332, -0.04849204,  0.00582178, -0.00935112,
#         0.02832552, -0.07539474, -0.0095126 , -0.03272327,  0.02527981,
#         0.04520037])
# array([ 0.01632278, -0.07508346, -0.02246798,  0.00279633, -0.00627641,
#         0.01106261, -0.04572691, -0.00368663, -0.02075328,  0.01896449,
#         0.0234088 ])

# %%
# print(X_train.shape,X_train.T.shape,np.linalg.inv(X_train.T * X_train))
# np.linalg. X_train.T * X_train
# X_train.to_numpy

# %%
import numpy as np
# w_lr = np.linalg.inv(X_train.transpose() * X_train) * X_train.transpose() * y_train
# w_lr
print(np.matmul(np.linalg.pinv(X_train),y_train),
      np.matmul(np.matmul(np.linalg.inv(np.matmul(X_train.T,X_train)),X_train.T),y_train),
      # np.matmul(np.linalg.pinv(X_train),y_train),
      # np.matmul(np.linalg.pinv(X_train),y_train)
      )
# Out:
# [ 0.20263355 -0.42745785 -0.33182736 -0.00666482 -0.00822139  0.26989156
#  -0.31150589 -0.08632161 -0.19337537  0.01986753  0.42410443] 0     0.202634
# 1    -0.427458
# 2    -0.331827
# 3    -0.006665
# 4    -0.008221
# 5     0.269892
# 6    -0.311506
# 7    -0.086322
# 8    -0.193375
# 9     0.019868
# 10    0.424104
# dtype: float64
# C:\Users\klkou\AppData\Local\Temp\ipykernel_22684\2886456756.py:5: FutureWarning: Calling a ufunc on non-aligned DataFrames (or DataFrame/Series combination). Currently, the indices are ignored and the result takes the index/columns of the first DataFrame. In the future , the DataFrames/Series will be aligned before applying the ufunc.
# Convert one of the arguments to a NumPy array (eg 'ufunc(df1, np.asarray(df2)') to keep the current behaviour, or align manually (eg 'df1, df2 = df1.align(df2)') before passing to the ufunc to obtain the future behaviour and silence this warning.
# ...
